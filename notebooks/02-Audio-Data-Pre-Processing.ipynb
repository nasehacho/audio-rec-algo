# %% [markdown]
# ## Task: Clean data to be used for our modeling
#
# Ex: Dropping null values, removing unnecessary columns, removing outliers, and potentially fixing incorrectly formatted data.

# %%
import pandas as pd
import matplotlib as plt 
import seaborn as sns 
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
audio_df = pd.read_csv('../data/tcc_ceds_music.csv')

# %%
audio_df.head()
# Out:
#    Unnamed: 0           artist_name            track_name  release_date genre  \
# 0           0                mukesh  mohabbat bhi jhoothi          1950   pop
# 1           4         frankie laine             i believe          1950   pop
# 2           6           johnnie ray                   cry          1950   pop
# 3          10           pérez prado              patricia          1950   pop
# 4          12  giorgos papadopoulos    apopse eida oneiro          1950   pop
#
#                                               lyrics  len    dating  violence  \
# 0  hold time feel break feel untrue convince spea...   95  0.000598  0.063746
# 1  believe drop rain fall grow believe darkest ni...   51  0.035537  0.096777
# 2  sweetheart send letter goodbye secret feel bet...   24  0.002770  0.002770
# 3  kiss lips want stroll charm mambo chacha merin...   54  0.048249  0.001548
# 4  till darling till matter know till dream live ...   48  0.001350  0.001350
#
#    world/life  ...   sadness  feelings  danceability  loudness  acousticness  \
# 0    0.000598  ...  0.380299  0.117175      0.357739  0.454119      0.997992
# 1    0.443435  ...  0.001284  0.001284      0.331745  0.647540      0.954819
# 2    0.002770  ...  0.002770  0.225422      0.456298  0.585288      0.840361
# 3    0.001548  ...  0.225889  0.001548      0.686992  0.744404      0.083935
# 4    0.417772  ...  0.068800  0.001350      0.291671  0.646489      0.975904
#
#    instrumentalness   valence    energy       topic  age
# 0          0.901822  0.339448  0.137110     sadness  1.0
# 1          0.000002  0.325021  0.263240  world/life  1.0
# 2          0.000000  0.351814  0.139112       music  1.0
# 3          0.199393  0.775350  0.743736    romantic  1.0
# 4          0.000246  0.597073  0.394375    romantic  1.0
#
# [5 rows x 31 columns]

# %%
# drop unecessary columns (non-numerical columns, columns with no significant insights)

audio_clean_df = audio_df.drop(['Unnamed: 0','lyrics', 'artist_name','track_name','genre','topic'], axis = 1)

# %%
audio_clean_df.head()
# Out:
#    release_date  len    dating  violence  world/life  night/time  \
# 0          1950   95  0.000598  0.063746    0.000598    0.000598
# 1          1950   51  0.035537  0.096777    0.443435    0.001284
# 2          1950   24  0.002770  0.002770    0.002770    0.002770
# 3          1950   54  0.048249  0.001548    0.001548    0.001548
# 4          1950   48  0.001350  0.001350    0.417772    0.001350
#
#    shake the audience  family/gospel  romantic  communication  ...  \
# 0            0.000598       0.048857  0.017104       0.263751  ...
# 1            0.001284       0.027007  0.001284       0.001284  ...
# 2            0.002770       0.002770  0.158564       0.250668  ...
# 3            0.021500       0.001548  0.411536       0.001548  ...
# 4            0.001350       0.001350  0.463430       0.001350  ...
#
#    like/girls   sadness  feelings  danceability  loudness  acousticness  \
# 0    0.000598  0.380299  0.117175      0.357739  0.454119      0.997992
# 1    0.001284  0.001284  0.001284      0.331745  0.647540      0.954819
# 2    0.002770  0.002770  0.225422      0.456298  0.585288      0.840361
# 3    0.081132  0.225889  0.001548      0.686992  0.744404      0.083935
# 4    0.001350  0.068800  0.001350      0.291671  0.646489      0.975904
#
#    instrumentalness   valence    energy  age
# 0          0.901822  0.339448  0.137110  1.0
# 1          0.000002  0.325021  0.263240  1.0
# 2          0.000000  0.351814  0.139112  1.0
# 3          0.199393  0.775350  0.743736  1.0
# 4          0.000246  0.597073  0.394375  1.0
#
# [5 rows x 25 columns]

# %%
# scale data for each column data to be treated equally and not dominate clustering (max-min value: 1-10)

# setting minimum value of each column to 0 and rescale to 1-10 
audio_clean_df = (audio_clean_df - audio_clean_df.min())/(audio_clean_df.max()- audio_clean_df.min()) * 9 + 1

# %%
# minumum and maximum value showcases successful scaling 

audio_clean_df.describe()
# Out:
#        release_date           len        dating      violence    world/life  \
# count  28372.000000  28372.000000  28372.000000  28372.000000  28372.000000
# mean       6.248290      4.274020      1.289440      2.083047      2.129263
# std        2.411408      1.901356      0.728017      1.638472      1.611326
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        4.260870      2.863636      1.008794      1.007660      1.008223
# 50%        6.347826      3.818182      1.016281      1.020373      1.058840
# 75%        8.434783      5.181818      1.052239      2.763540      2.848090
# max       10.000000     10.000000     10.000000     10.000000     10.000000
#
#          night/time  shake the audience  family/gospel      romantic  \
# count  28372.000000        28372.000000   28372.000000  28372.000000
# mean       1.527926            1.310233       1.276701      1.463122
# std        1.034841            0.736218       0.692994      1.015260
# min        1.000000            1.000000       1.000000      1.000000
# 25%        1.006868            1.012826       1.010472      1.006604
# 50%        1.015350            1.023721       1.020057      1.014066
# 75%        1.606102            1.175902       1.074236      1.402073
# max       10.000000           10.000000      10.000000     10.000000
#
#        communication  ...    like/girls       sadness      feelings  \
# count   28372.000000  ...  28372.000000  28372.000000  28372.000000
# mean        2.065003  ...      1.420672      2.184279      1.288323
# std         1.527166  ...      0.885692      1.661624      0.672771
# min         1.000000  ...      1.000000      1.000000      1.000000
# 25%         1.011898  ...      1.010454      1.007886      1.006609
# 50%         1.032635  ...      1.019849      1.045669      1.013757
# 75%         2.838166  ...      1.398932      3.154080      1.303584
# max        10.000000  ...     10.000000     10.000000     10.000000
#
#        danceability      loudness  acousticness  instrumentalness  \
# count  28372.000000  28372.000000  28372.000000      28372.000000
# mean       5.808684      6.987243      4.053111          1.722635
# std        1.577759      0.975907      2.940429          1.906998
# min        1.000000      1.000000      1.000000          1.000000
# 25%        4.712266      6.358280      1.308121          1.000000
# 50%        5.856626      7.111453      3.033124          1.000767
# 75%        6.931930      7.741231      6.692767          1.084266
# max       10.000000     10.000000     10.000000         10.000000
#
#             valence        energy           age
# count  28372.000000  28372.000000  28372.000000
# mean       5.795774      6.128875      4.751710
# std        2.258747      2.199465      2.411408
# min        1.000000      1.000000      1.000000
# 25%        3.962284      4.423249      2.565217
# 50%        5.854287      6.225107      4.652174
# 75%        7.644270      7.954891      6.739130
# max       10.000000     10.000000     10.000000
#
# [8 rows x 25 columns]

# %%
# save dataframe as a new csv file to be used in the next step

audio_clean_df.to_csv('../data/audio_cleaned.csv')
