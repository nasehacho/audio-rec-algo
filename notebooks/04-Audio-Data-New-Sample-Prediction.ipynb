# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# %%
rec_df = pd.read_csv('../data/recommend.csv')

# %%
rec_df.head()
# Out:
#    Unnamed: 0       artist_name           track_name  release_date   genre  \
# 0       76885          godsmack               immune          1998    rock
# 1       65394      dennis brown        second chance          1993  reggae
# 2       10980  the black crowes          sister luck          1990     pop
# 3         842   jerry lee lewis  your cheating heart          1960     pop
# 4        2764         paul anka             eso beso          1966     pop
#
#                                               lyrics  len    dating  violence  \
# 0  come world society futher place home land deat...   74  0.000907  0.348191
# 1  maybe maybe treat good feel second best girl s...   43  0.001224  0.029943
# 2  worry sick eye hurt rest head life outside gir...   54  0.001120  0.482490
# 3  cheat heart weep sleep sleep come night cheat ...   25  0.204740  0.002506
# 4  beso kiss beso kiss know samba bossanova close...   97  0.001170  0.001170
#
# ...

# %%
rec_df_clean = rec_df.drop(['Unnamed: 0','artist_name','lyrics','track_name','genre', 'topic'], axis=1)

# %%
# apply trained machine learning algorithm

kmeans = KMeans(n_clusters=3)

# save cluster assignments to new column in rec_df

rec_df_clean['Cluster'] = kmeans.fit_predict(rec_df_clean)
# Out:
# /Users/nasehacho/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
rec_df_clean
# Out:
#    release_date  len    dating  violence  world/life  night/time  \
# 0          1998   74  0.000907  0.348191    0.375448    0.000907
# 1          1993   43  0.001224  0.029943    0.001224    0.306688
# 2          1990   54  0.001120  0.482490    0.001120    0.001120
# 3          1960   25  0.204740  0.002506    0.002506    0.129818
# 4          1966   97  0.001170  0.001170    0.001170    0.050289
# 5          1952   57  0.001462  0.487965    0.140561    0.001462
# 6          2000  152  0.000675  0.000675    0.134044    0.293819
# 7          1970   37  0.051874  0.001645    0.001645    0.084118
# 8          1986   41  0.001504  0.001504    0.132148    0.492312
# 9          2009   91  0.000711  0.543658    0.114697    0.098286
#
#    shake the audience  family/gospel  romantic  communication   obscene  \
# 0            0.225414       0.000907  0.000907       0.000907  0.000907
# 1            0.001224       0.033440  0.069637       0.426669  0.001224
# ...

# %%
label = rec_df[['genre', 'artist_name','track_name']]

label = pd.concat([label, rec_df_clean], axis=1)

# %%
label[rec_df_clean['Cluster'] ==0]
# Out:
#   genre artist_name   track_name  release_date  len    dating  violence  \
# 0  rock    godsmack       immune          1998   74  0.000907  0.348191
# 4   pop   paul anka     eso beso          1966   97  0.001170  0.001170
# 9   pop    paramore  playing god          2009   91  0.000711  0.543658
#
#    world/life  night/time  shake the audience  ...   obscene     music  \
# 0    0.375448    0.000907            0.225414  ...  0.000907  0.019389
# 4    0.001170    0.050289            0.001170  ...  0.001170  0.001170
# 9    0.114697    0.098286            0.014720  ...  0.000711  0.000711
#
#    movement/places  light/visual perceptions  family/spiritual  like/girls  \
# 0         0.000907                  0.000907          0.000907    0.000907
# 4         0.001170                  0.314626          0.001170    0.053731
# 9         0.000711                  0.000711          0.000711    0.000711
#
#     sadness  feelings       age  Cluster
# 0  0.000907  0.018854  0.314286        0
# ...

# %%
label[rec_df_clean['Cluster'] ==1]
# Out:
#      genre       artist_name            track_name  release_date  len  \
# 1   reggae      dennis brown         second chance          1993   43
# 2      pop  the black crowes           sister luck          1990   54
# 3      pop   jerry lee lewis   your cheating heart          1960   25
# 5     jazz      noro morales              silencio          1952   57
# 7    blues             taste       railway and gun          1970   37
# 8  country      randy travis  messin' with my mind          1986   41
#
#      dating  violence  world/life  night/time  shake the audience  ...  \
# 1  0.001224  0.029943    0.001224    0.306688            0.001224  ...
# 2  0.001120  0.482490    0.001120    0.001120            0.001120  ...
# 3  0.204740  0.002506    0.002506    0.129818            0.002506  ...
# 5  0.001462  0.487965    0.140561    0.001462            0.001462  ...
# 7  0.051874  0.001645    0.001645    0.084118            0.037341  ...
# ...

# %%
label[rec_df_clean['Cluster'] ==2]
# Out:
#   genre               artist_name        track_name  release_date  len  \
# 6  rock  rage against the machine  pistol grip pump          2000  152
#
#      dating  violence  world/life  night/time  shake the audience  ...  \
# 6  0.000675  0.000675    0.134044    0.293819            0.000675  ...
#
#     obscene     music  movement/places  light/visual perceptions  \
# 6  0.460145  0.000675         0.000675                  0.000675
#
#    family/spiritual  like/girls   sadness  feelings       age  Cluster
# 6          0.024217    0.000675  0.000675  0.000675  0.285714        2
#
# [1 rows x 23 columns]
